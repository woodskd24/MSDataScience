# %% [markdown]
# <a href="https://colab.research.google.com/github/woodskd24/MSDataScience/blob/main/Analysis_for_Steph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Packages**

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**Load Dataset**

# %%
TV=pd.read_csv("/content/StephTV.csv")
TV
# Out:
#     Watched                  Title  Seasons Avg. Episode Length  \
# 0     False        ¿Qué Pasa, USA?      4.0          27 minutes
# 1     False   American Crime Story      1.0          60 minutes
# 2     False  Angel (Buffy Spinoff)      5.0          45 minutes
# 3     False             Archive 81      1.0          50 minutes
# 4     False        Behind Her Eyes      1.0          50 minutes
# ..      ...                    ...      ...                 ...
# 103   False                    NaN      NaN                 NaN
# 104   False                    NaN      NaN                 NaN
# 105   False                    NaN      NaN                 NaN
# 106   False                    NaN      NaN                 NaN
# 107   False                    NaN      NaN                 NaN
#
#      Year Premiered            Genre    Drama Level Quote  \
# 0            1977.0  Cultural sitcom   Cuban Family   NaN
# 1            2016.0       Docuseries     True Crime   NaN
# ...

# %% [markdown]
# #**Descriptive Stats**

# %%
TV.describe()
# Out:
#          Seasons  Year Premiered
# count  77.000000       77.000000
# mean    3.974026     2013.610390
# std     2.640644        8.558092
# min     1.000000     1977.000000
# 25%     2.000000     2012.000000
# 50%     3.000000     2016.000000
# 75%     6.000000     2019.000000
# max    11.000000     2022.000000

# %%
TV.corr()
# Out:
#                  Seasons  Year Premiered
# Seasons         1.000000       -0.669444
# Year Premiered -0.669444        1.000000

# %%
TV.cov()
# Out:
#                   Seasons  Year Premiered
# Seasons          6.973001      -15.128674
# Year Premiered -15.128674       73.240943

# %% [markdown]
# #**Genre**

# %%
#Genre = TV[["Family oriented" + "Friends oriented" + "Romance oriented" + "Work/School oriented" + "Crime oriented"]]
def Focus(TV):
   if TV['Family'] == "X":
      return 'Family'
   if TV['Friends'] == "X":
      return 'Friends'
   if TV['Romance'] == "X":
      return 'Romance'
   if TV['Work_school'] == "X":
      return 'WorkSchool'
   if TV['Crime'] == "X":
      return 'Crime'
   return 'Other'

# %%
TV.apply(lambda TV: Focus(TV), axis=1)
# Out:
# 0          Family
# 1           Crime
# 2         Friends
# 3      WorkSchool
# 4          Family
#           ...
# 103         Other
# 104         Other
# 105         Other
# 106         Other
# 107         Other
# Length: 108, dtype: object

# %%
TV['Focus'] = TV.apply(lambda TV: Genre(TV), axis=1)

# %%
sns.boxplot(x = "Focus", y = "Seasons", data = TV)

# %%
import numpy as np

# %%
TV['Genre'].value_counts()
# Out:
# Drama              30
# Sitcom             15
# Dramedy            11
# Cultural sitcom     6
# Docuseries          6
# Dance Drama         3
# Comedy              3
# Rom-Com             1
# Adult animation     1
# Thriller            1
# Name: Genre, dtype: int64

# %%
TV.count()
# Out:
# Watched                              107
# Title                                 77
# Seasons                               77
# Avg. Episode Length                   77
# Year Premiered                        77
# Genre                                 77
# Drama Level                           37
# Quote                                 32
# Holy Grail aka Steph's favorites       6
# Can Watch Repeatedly                  13
# A Good Cry                             1
# Family                                32
# Friends                               28
# Romance                               28
# Work_school                           32
# Crime                                 21
# Who especially should watch this?     12
# Where to Stream                       76
# Focus                                108
# dtype: int64
